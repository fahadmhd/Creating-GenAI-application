# %% [markdown]
# <a href="https://colab.research.google.com/github/fahadmhd/Creating-GenAI-application/blob/main/Testing_langchain_huggingface.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install langchain-huggingface
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.4/50.4 kB 2.2 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# ...
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# ...

# %%
## For API Calls
# !pip install huggingface_hub
# !pip install transformers
# !pip install accelerate
# !pip install  bitsandbytes
# !pip install langchain
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.5/137.5 MB 6.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 997.8/997.8 kB 17.0 MB/s eta 0:00:00
# ...

# %%
from google.colab import userdata
sec_key=userdata.get("HF_TOKEN")

# %%
from langchain_huggingface import HuggingFaceEndpoint

# %%
from google.colab import userdata
sec_key=userdata.get("HUGGINGFACEHUB_API_TOKEN")

# %%
import os
os.environ["HUGGINGFACEHUB_API_TOKEN"]=sec_key

# %%
repo_id="mistralai/Mistral-7B-Instruct-v0.2"
llm=HuggingFaceEndpoint(repo_id=repo_id,max_length=128,temperature=0.7,token=sec_key)
# Out:
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! max_length is not default parameter.
#                     max_length was transferred to model_kwargs.
#                     Please make sure that max_length is what you intended.
# WARNING:langchain_huggingface.llms.huggingface_endpoint:WARNING! token is not default parameter.
#                     token was transferred to model_kwargs.
#                     Please make sure that token is what you intended.
# The token has not been saved to the git credentials helper. Pass `add_to_git_credential=True` in this function directly or `--add-to-git-credential` if using via `huggingface-cli` if you want to set the git credential as well.
# Token is valid (permission: fineGrained).
# Your token has been saved to /root/.cache/huggingface/token
# Login successful

# %%
llm.invoke("What is the status of semantic web stack?")
# Out:
# " Is it still being actively developed?\n\nThe semantic web stack, which includes technologies such as RDF, SPARQL, and OWL, is still being actively developed. There are ongoing efforts to improve and extend these technologies to better support the needs of the semantic web community. For example, there have been recent releases of new versions of popular RDF databases like Blazegraph and Virtuoso, which include new features and performance improvements. There are also ongoing efforts to develop new semantic web technologies, such as the W3C's Web Annotation and Linked Data Platform specifications. Additionally, there is continued research and development in the area of semantic web applications and use cases, which helps to drive the development of new features and capabilities in the underlying technologies. Overall, the semantic web stack remains an active area of research and development, and there is a strong community of developers and researchers working to advance the state o
# ...

# %%
llm.invoke("Do we need ontologies in LLM?")
# Out:
# '\n\nI have seen the term "ontology" used in the context of LLM, particularly in the context of legal knowledge representation and reasoning systems. However, I am not entirely clear on what an ontology is or why it is necessary in the context of LLM.\n\nIn general, an ontology is a formal representation of knowledge in a specific domain. It specifies the concepts and relationships that exist within that domain, as well as the rules for inferring new knowledge based on the existing knowledge. Ontologies can be used to represent complex and interconnected knowledge domains, and they can be used to facilitate communication and information exchange between different systems and organizations.\n\nIn the context of LLM, ontologies can be used to represent legal concepts and relationships. For example, an ontology might include concepts such as "contract," "obligation," and "breach," and it might specify relationships between these concepts, such as "a breach of contract gives rise to a cl
# ...

# %%
from langchain import PromptTemplate, LLMChain

question="updated of olympics France 2024?"
template = """Question: {question}
Answer: Let's think step by step."""
prompt = PromptTemplate(template=template, input_variables=["question"])
print(prompt)
# Out:
# input_variables=['question'] template="Question: {question}\nAnswer: Let's think step by step."

# %%
llm_chain=LLMChain(llm=llm,prompt=prompt)
print(llm_chain.invoke(question))
# Out:
# {'question': 'updated of olympics France 2024?', 'text': ' The Olympic Games were last held in Tokyo, Japan, in 2021 due to the pandemic. The next summer Olympic Games are scheduled to take place in Paris, France, in 2024. This information is based on the official schedule of the International Olympic Committee. Therefore, the information about the Olympics France 2024 is up-to-date and accurate.'}

# %% [markdown]
# heading

# %%
from langchain_huggingface import HuggingFacePipeline
from transformers import AutoModelForCausalLM, AutoTokenizer, pipeline

# %%
model_id="gpt2"
model=AutoModelForCausalLM.from_pretrained(model_id)
tokenizer=AutoTokenizer.from_pretrained(model_id)
# Out:
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
pipe=pipeline("text-generation",model=model,tokenizer=tokenizer,max_new_tokens=100)
hf=HuggingFacePipeline(pipeline=pipe)

# %%
hf.invoke("give me highlights of olympics 2024")
# Out:
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# 'give me highlights of olympics 2024 and 2025, and my comments on the future of olympics 2020." You can hear them on his official website – he just created his first book.\n\nOn twitter: @_dollarsign, @The_Dollarsign\n\nPlease read their full remarks at the end of this story.'
